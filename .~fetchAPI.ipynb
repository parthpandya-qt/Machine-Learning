# %%
import pandas as pd 
import requests

# %%
data = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=dbd9db6d42527c19b52f5b9bb26d979d&language=en-US&page=1")

# %%
df = pd.DataFrame(data.json()['results'])

# %%
df.head()
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False   /zMwhWailP1WY7sb6AoE6b8ugoy.jpg  [12, 16, 10751, 14]  1007757
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg             [18, 80]      278
# 2  False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg             [18, 80]      238
# 3  False  /2I1OFQJ0L9T0dpU6FobKFWV2PxX.jpg            [878, 12]   687163
# 4  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg             [18, 80]      240
#
#                       title original_language            original_title  \
# 0                   Swapped                en                   Swapped
# 1  The Shawshank Redemption                en  The Shawshank Redemption
# 2             The Godfather                en             The Godfather
# 3         Project Hail Mary                en         Project Hail Mary
# 4     The Godfather Part II                en     The Godfather Part II
#
#                                             overview  popularity  \
# ...

# %%
df = pd.DataFrame()

# %%
for i in range(1, 429):
    try:
        url = f"https://api.themoviedb.org/3/movie/top_rated?api_key=YOUR_API_KEY&language=en-US&page={i}"
        data = requests.get(url, timeout=10)

        temp = pd.DataFrame(data.json()['results'])[
            ['id', 'title', 'overview', 'release_date', 'popularity']
        ]

        df = pd.concat([df, temp], ignore_index=True)

    except Exception as e:
        print(f"Page {i}: {e}")
# Out:
# Page 1: 'results'
# Page 2: 'results'
# Page 3: 'results'
# Page 4: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/top_rated?api_key=YOUR_API_KEY&language=en-US&page=4 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Page 5: 'results'
# Page 6: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/top_rated?api_key=YOUR_API_KEY&language=en-US&page=6 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Page 7: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/movie/top_rated?api_key=YOUR_API_KEY&language=en-US&page=7 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# ...

# %%
df.shape
# Out:
# (0, 0)
