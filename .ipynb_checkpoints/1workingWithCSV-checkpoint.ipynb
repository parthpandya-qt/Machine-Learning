# %%
import pandas as pd

# %%
#read the CSV file
df = pd.read_csv('WorldCupMatches.csv')

# %%
#print top 5 dataset
df.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
# opening CSV file from an URL
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"

headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"
}

req = requests.get(url, headers=headers)

data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
#Sep Parameter used for generally TSV files
#pd.read_csv('movies.tsv',sep='\t')

# %%
df = pd.read_csv('WorldCupMatches.csv',index_col='Year')
df.head()  #convert one of the column to index
# Out:
#                     Datetime    Stage         Stadium         City  \
# Year
# 1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#        Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# Year
# 1930.0         France              4.0              1.0         Mexico
# 1930.0            USA              3.0              0.0        Belgium
# 1930.0     Yugoslavia              2.0              1.0         Brazil
# 1930.0        Romania              3.0              1.0           Peru
# 1930.0      Argentina              1.0              0.0         France
#
#        Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# Year
# ...

# %%
#pd.read_csv('WorldCupMatches.csv' header=1)  
#"Use the second row (index 1) as the column names."

# %%
pd.read_csv('WorldCupMatches.csv' , usecols = ['Year','Stadium'])
#Reads only the specified columns from the CSV file.
# Out:
#         Year         Stadium
# 0     1930.0         Pocitos
# 1     1930.0  Parque Central
# 2     1930.0  Parque Central
# 3     1930.0         Pocitos
# 4     1930.0  Parque Central
# ...      ...             ...
# 4567     NaN             NaN
# 4568     NaN             NaN
# 4569     NaN             NaN
# 4570     NaN             NaN
# 4571     NaN             NaN
#
# [4572 rows x 2 columns]

# %%
pd.read_csv('WorldCupMatches.csv' , skiprows=[0,1])
#Skips rows 0 and 1 while reading the CSV.
# Out:
#         1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo   \
# 0     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 1     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 2     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 3     1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 4     1930.0  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4565     NaN                   NaN      NaN             NaN          NaN
# 4566     NaN                   NaN      NaN             NaN          NaN
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
#
#              USA    3    0  Belgium         18346    2  0.1  \
# ...

# %%
pd.read_csv('WorldCupMatches.csv' , nrows = 100)
#Reads only the first 100 rows from the CSV file.
# Out:
#     Year              Datetime                  Stage           Stadium  \
# 0   1930  13 Jul 1930 - 15:00                 Group 1           Pocitos
# 1   1930  13 Jul 1930 - 15:00                 Group 4    Parque Central
# 2   1930  14 Jul 1930 - 12:45                 Group 2    Parque Central
# 3   1930  14 Jul 1930 - 14:50                 Group 3           Pocitos
# 4   1930  15 Jul 1930 - 16:00                 Group 1    Parque Central
# ..   ...                   ...                    ...               ...
# 95  1954  27 Jun 1954 - 17:00          Quarter-finals        Charmilles
# 96  1954  27 Jun 1954 - 17:00          Quarter-finals  Wankdorf Stadium
# 97  1954  30 Jun 1954 - 18:00             Semi-finals         St. Jakob
# 98  1954  30 Jun 1954 - 18:00             Semi-finals       La Pontaise
# 99  1954  03 Jul 1954 - 17:00   Match for third place          Hardturm
#
#            City Home Team Name  Home Team Goals  Away Team Goals  \
# ...

# %%
#pd.read_csv('WorldCupMatches.csv',encoding='latin-1' )
#Tells Pandas how to interpret the text characters in the file.

# %%
#pd.read_csv('WorldCupMatches.csv',dtype={'MatchID':int})
#Forces a column to be read as a specific data type.

# %%
pd.read_csv('WorldCupMatches.csv',parse_dates= ['Datetime']).info()
#Converts the Datetime column from a string (object) to a Pandas datetime type (datetime64[ns]) while reading the CSV.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
def rename(name):
    if name == 'France':
        return "Fr"
    else:
        return name

# %%
pd.read_csv('WorldCupMatches.csv',converters={'Home Team Name':rename})
#Applies a custom function to every value in the specified column while reading the CSV.
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
#pd.read_csv('WorldCupMatches.csv', na_values=['Male'])
#reats specified values as missing values (NaN) when reading the CSV.

# %%
dfs = pd.read_csv('WorldCupMatches.csv',chunksize = 50)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# (50, 20)
# ...
