# %%
import numpy as np
zeroD = np.array(4)
print(zeroD)
print(zeroD.ndim)

# %%
oneD = np.array([4,6,7])
print(oneD)
print(oneD.ndim)

# %%
twoD = np.array([[24,53,32],[6,53,23]])
print(twoD)

# %%
threeD = np.array([[[24,53,32],[6,53,23]],[[24,53,32],[6,53,23]]])
print(threeD)
print(threeD.ndim)

# %%
fourD=np.array([[[[24,53,32],[6,53,23]],[[24,53,32],[6,53,23]]],[[[24,53,32],[6,53,23]],[[24,53,32],[6,53,23]]]])
print(fourD)
print(fourD.ndim)

# %%
fiveD = np.array([[[[[24,53,32],[6,53,23]],[[24,53,32],[6,53,23]]],[[[24,53,32],[6,53,23]],[[24,53,32],[6,53,23]]]],[[[[24,53,32],[6,53,23]],[[24,53,32],[6,53,23]]],[[[24,53,32],[6,53,23]],[[24,53,32],[6,53,23]]]]])
print(fiveD)
print(fiveD.ndim)
