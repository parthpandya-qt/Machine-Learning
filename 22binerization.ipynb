# %%
# binarization: converting a numerical variable into a binary variable based on a threshold value.
# binning: converting a numerical variable into a categorical variable by grouping the values into bins or

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv("train.csv",usecols=["Age","Fare","SibSp","Parch","Survived"])

# %%
df.dropna(inplace=True)

# %%
df["family"] = df["SibSp"] + df["Parch"]

# %%
df.drop(["SibSp","Parch"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived   Age     Fare  family
# 0         0  22.0   7.2500       1
# 1         1  38.0  71.2833       1
# 2         1  26.0   7.9250       0
# 3         1  35.0  53.1000       1
# 4         0  35.0   8.0500       0

# %%
x = df[["Age","Fare","family"]]
y = df['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x

# %%
x_train.head()
# Out:
#       Age     Fare  family
# 387  36.0  13.0000       0
# 685  25.0  41.5792       3
# 20   35.0  26.0000       0
# 331  45.5  28.5000       0
# 396  31.0   7.8542       0

# %%
from sklearn.preprocessing import Binarizer

# %%
trf = ColumnTransformer([
    ("binarization", Binarizer(copy=False), ["family"]),
], remainder="passthrough")

# %%
x_train_trf = trf.fit_transform(x_train)
x_test_trf = trf.transform(x_test)
